# %% [markdown]
# Generating datasets
#
# For each Split dataset, information about the index of the highly discriminative attribute is in the output

# %% [markdown]
# (3,3) Dataset with no length cost and vocab size 13

# %% [markdown]
# Split

# %%
# !python train.py \
  --dimensions 3 3 3 \
  --n_epochs 300 \
  --batch_size 32 \
  --game_size 10 \
  --scaling_factor 10 \
  --shared_context True \
  --split_by_attribute True \
  --early_stopping True \
  --save_test_interactions_as test_split_3_3 \
  --save_test_interactions True \
  --save True
# Out:
# Using EGG from: C:\Users\metel\OneDrive\Desktop\EGG-final\EGG\egg\__init__.py
# Creating subsets A and B based on randomly chosen attribute. Attribute index: 1
# Subset A size: 480
# C:\Users\metel\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\metel\AppData\Roaming\Python\Python39\site-packages\pandas\core\arrays\masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.4' currently installed).
#   from pandas.core import (
#
# ...
# 100%|██████████| 63/63 [00:02<00:00, 25.18it/s]
# Subset B size: 960
#
# Final Dataset Sizes:
# Train dataset size: 450
# Validation dataset size: 150
# Test dataset size: 840
# vocab size 13
# message length 3
# ...

# %%
# run 1
# !python train.py \
  --dimensions 3 3 3 \
  --n_epochs 300 \
  --batch_size 32 \
  --game_size 10 \
  --scaling_factor 10 \
  --shared_context True \
  --split_by_attribute True \
  --early_stopping True \
  --save_test_interactions_as test_split_3_3_run1 \
  --save_test_interactions True \
  --save True
# Out:
# Using EGG from: C:\Users\metel\OneDrive\Desktop\EGG-final\EGG\egg\__init__.py
# Creating subsets A and B based on randomly chosen attribute. Attribute index: 0
# Subset A size: 480
# Subset B size: 960
# C:\Users\metel\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\metel\AppData\Roaming\Python\Python39\site-packages\pandas\core\arrays\masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.4' currently installed).
#   from pandas.core import (
#
# ...
# 100%|██████████| 63/63 [00:02<00:00, 27.20it/s]
# Final Dataset Sizes:
# Train dataset size: 450
# Validation dataset size: 150
# Test dataset size: 840
# vocab size 13
# message length 3
# ...

# %%
# run 2
# !python train.py \
  --dimensions 3 3 3 \
  --n_epochs 300 \
  --batch_size 32 \
  --game_size 10 \
  --scaling_factor 10 \
  --shared_context True \
  --split_by_attribute True \
  --early_stopping True \
  --save_test_interactions_as test_split_3_3_run2 \
  --save_test_interactions True \
  --save True
# Out:
# Using EGG from: C:\Users\metel\OneDrive\Desktop\EGG-final\EGG\egg\__init__.py
# C:\Users\metel\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\metel\AppData\Roaming\Python\Python39\site-packages\pandas\core\arrays\masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.4' currently installed).
#   from pandas.core import (
#
# ...
# 100%|██████████| 63/63 [00:02<00:00, 23.50it/s]
# Creating subsets A and B based on randomly chosen attribute. Attribute index: 2
# Subset A size: 480
# Subset B size: 960
#
# Final Dataset Sizes:
# Train dataset size: 450
# Validation dataset size: 150
# Test dataset size: 840
# vocab size 13
# message length 3
# ...

# %%
# run 3
# !python train.py \
  --dimensions 3 3 3 \
  --n_epochs 300 \
  --batch_size 32 \
  --game_size 10 \
  --scaling_factor 10 \
  --shared_context True \
  --split_by_attribute True \
  --early_stopping True \
  --save_test_interactions_as test_split_3_3_run3 \
  --save_test_interactions True \
  --save True
# Out:
# Using EGG from: C:\Users\metel\OneDrive\Desktop\EGG-final\EGG\egg\__init__.py
# Creating subsets A and B based on randomly chosen attribute. Attribute index: 1
# Subset A size: 480
# Subset B size: 960
#
# Final Dataset Sizes:
# Train dataset size: 450
# Validation dataset size: 150
# Test dataset size: 840
# vocab size 13
# message length 3
# {"loss": 0.701930582523346, "acc": 0.48896339535713196, "length": 3.4029526710510254, "mode": "train", "epoch": 1}
# {"loss": 0.6974170207977295, "acc": 0.44609376788139343, "length": 1.0, "mode": "test", "epoch": 1}
# {"loss": 0.6952718496322632, "acc": 0.5141332745552063, "length": 2.733962297439575, "mode": "train", "epoch": 2}
# {"loss": 0.6932549476623535, "acc": 0.501953125, "length": 1.0, "mode": "test", "epoch": 2}
# {"loss": 0.6894980072975159, "acc": 0.5321159958839417, "length": 2.0503365993499756, "mode": "train", "epoch": 3}
# {"loss": 0.6718522310256958, "acc": 0.624560534954071, "length": 1.8671875, "mode": "test", "epoch": 3}
# ...

# %%
# run 4
# !python train.py \
  --dimensions 3 3 3 \
  --n_epochs 300 \
  --batch_size 32 \
  --game_size 10 \
  --scaling_factor 10 \
  --shared_context True \
  --split_by_attribute True \
  --early_stopping True \
  --save_test_interactions_as test_split_3_3_run4 \
  --save_test_interactions True \
  --save True
# Out:
# Using EGG from: C:\Users\metel\OneDrive\Desktop\EGG-final\EGG\egg\__init__.py
# Creating subsets A and B based on randomly chosen attribute. Attribute index: 0
# Subset A size: 480
# Subset B size: 960
#
# Final Dataset Sizes:
# Train dataset size: 450
# Validation dataset size: 150
# Test dataset size: 840
# vocab size 13
# message length 3
# {"loss": 0.6990237832069397, "acc": 0.4948781132698059, "length": 3.458754301071167, "mode": "train", "epoch": 1}
# {"loss": 0.6908351182937622, "acc": 0.5257812142372131, "length": 1.0, "mode": "test", "epoch": 1}
# {"loss": 0.6932202577590942, "acc": 0.5079900622367859, "length": 2.8806071281433105, "mode": "train", "epoch": 2}
# {"loss": 0.6937723159790039, "acc": 0.5023437142372131, "length": 1.0, "mode": "test", "epoch": 2}
# {"loss": 0.6773435473442078, "acc": 0.6099799275398254, "length": 2.9007680416107178, "mode": "train", "epoch": 3}
# {"loss": 0.6506226062774658, "acc": 0.666015625, "length": 2.96875, "mode": "test", "epoch": 3}
# ...

# %% [markdown]
# Normal (shared_context, no split)

# %%
# !python train.py \
  --dimensions 3 3 3 \
  --n_epochs 300 \
  --batch_size 32 \
  --game_size 10 \
  --scaling_factor 10 \
  --shared_context True \
  --early_stopping True \
  --save_test_interactions_as test_shared_3_3 \
  --save_test_interactions True \
  --save True
# Out:
# Using EGG from: C:\Users\metel\OneDrive\Desktop\EGG-final\EGG\egg\__init__.py
# Creating train_ds and val_ds...
#
# Creating test_ds...
# vocab size 13
# message length 3
# {"loss": 0.6939274072647095, "acc": 0.5314107537269592, "length": 3.403225898742676, "mode": "train", "epoch": 1}
# {"loss": 0.6860169172286987, "acc": 0.5214110612869263, "length": 1.2578125, "mode": "test", "epoch": 1}
# {"loss": 0.6365951895713806, "acc": 0.6364055275917053, "length": 3.318220853805542, "mode": "train", "epoch": 2}
# {"loss": 0.5585108995437622, "acc": 0.7205077409744263, "length": 4.0, "mode": "test", "epoch": 2}
# {"loss": 0.49897149205207825, "acc": 0.7544376850128174, "length": 3.900796413421631, "mode": "train", "epoch": 3}
# {"loss": 0.4702407121658325, "acc": 0.7855468392372131, "length": 4.0, "mode": "test", "epoch": 3}
# {"loss": 0.39311298727989197, "acc": 0.8123102784156799, "length": 3.9264276027679443, "mode": "train", "epoch": 4}
# ...

# %%
# !python train.py \
  --dimensions 3 3 3 \
  --n_epochs 300 \
  --batch_size 32 \
  --game_size 10 \
  --scaling_factor 10 \
  --shared_context True \
  --early_stopping True \
  --save_test_interactions_as test_shared_3_3_run1 \
  --save_test_interactions True \
  --save True
# Out:
# Using EGG from: C:\Users\metel\OneDrive\Desktop\EGG-final\EGG\egg\__init__.py
# Creating train_ds and val_ds...
#
# Creating test_ds...
# vocab size 13
# message length 3
# {"loss": 0.6997383832931519, "acc": 0.5111953020095825, "length": 3.163275718688965, "mode": "train", "epoch": 1}
# {"loss": 0.6947941184043884, "acc": 0.5141113996505737, "length": 1.015625, "mode": "test", "epoch": 1}
# {"loss": 0.6407778859138489, "acc": 0.6487140655517578, "length": 2.5433716773986816, "mode": "train", "epoch": 2}
# {"loss": 0.5914403796195984, "acc": 0.703533947467804, "length": 2.6171875, "mode": "test", "epoch": 2}
# {"loss": 0.5387976169586182, "acc": 0.7283483743667603, "length": 2.819826602935791, "mode": "train", "epoch": 3}
# {"loss": 0.5326681137084961, "acc": 0.754302978515625, "length": 2.9921875, "mode": "test", "epoch": 3}
# {"loss": 0.453816682100296, "acc": 0.7689447402954102, "length": 3.0397872924804688, "mode": "train", "epoch": 4}
# ...

# %%
# !python train.py \
  --dimensions 3 3 3 \
  --n_epochs 300 \
  --batch_size 32 \
  --game_size 10 \
  --scaling_factor 10 \
  --shared_context True \
  --early_stopping True \
  --save_test_interactions_as test_shared_3_3_run2 \
  --save_test_interactions True \
  --save True
# Out:
# Using EGG from: C:\Users\metel\OneDrive\Desktop\EGG-final\EGG\egg\__init__.py
# Creating train_ds and val_ds...
#
# Creating test_ds...
# vocab size 13
# message length 3
# {"loss": 0.6964960694313049, "acc": 0.5123634934425354, "length": 3.3832926750183105, "mode": "train", "epoch": 1}
# {"loss": 0.6760212182998657, "acc": 0.6148817539215088, "length": 2.125, "mode": "test", "epoch": 1}
# {"loss": 0.6155309081077576, "acc": 0.6745274662971497, "length": 3.4782986640930176, "mode": "train", "epoch": 2}
# {"loss": 0.5819661617279053, "acc": 0.7208333015441895, "length": 4.0, "mode": "test", "epoch": 2}
# {"loss": 0.5169312953948975, "acc": 0.728004515171051, "length": 3.9246015548706055, "mode": "train", "epoch": 3}
# {"loss": 0.4606485962867737, "acc": 0.7605903148651123, "length": 4.0, "mode": "test", "epoch": 3}
# {"loss": 0.39295411109924316, "acc": 0.8199146389961243, "length": 3.9413838386535645, "mode": "train", "epoch": 4}
# ...

# %%
# !python train.py \
  --dimensions 3 3 3 \
  --n_epochs 300 \
  --batch_size 32 \
  --game_size 10 \
  --scaling_factor 10 \
  --shared_context True \
  --early_stopping True \
  --save_test_interactions_as test_shared_3_3_run3 \
  --save_test_interactions True \
  --save True
# Out:
# Using EGG from: C:\Users\metel\OneDrive\Desktop\EGG-final\EGG\egg\__init__.py
# Creating train_ds and val_ds...
# C:\Users\metel\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# Creating test_ds...
# vocab size 13
# message length 3
# {"loss": 0.6992318034172058, "acc": 0.5168910026550293, "length": 3.213228464126587, "mode": "train", "epoch": 1}
# {"loss": 0.6954259872436523, "acc": 0.49492189288139343, "length": 1.0, "mode": "test", "epoch": 1}
# {"loss": 0.6542820334434509, "acc": 0.6323181986808777, "length": 2.369006395339966, "mode": "train", "epoch": 2}
# {"loss": 0.5752063989639282, "acc": 0.704418957233429, "length": 2.37109375, "mode": "test", "epoch": 2}
# ...

# %%
# !python train.py \
  --dimensions 3 3 3 \
  --n_epochs 300 \
  --batch_size 32 \
  --game_size 10 \
  --scaling_factor 10 \
  --shared_context True \
  --early_stopping True \
  --save_test_interactions_as test_shared_3_3_run4 \
  --save_test_interactions True \
  --save True
# Out:
# Using EGG from: C:\Users\metel\OneDrive\Desktop\EGG-final\EGG\egg\__init__.py
# Creating train_ds and val_ds...
#
# Creating test_ds...
# vocab size 13
# message length 3
# {"loss": 0.6910822987556458, "acc": 0.5362169146537781, "length": 3.377589225769043, "mode": "train", "epoch": 1}
# {"loss": 0.6784299612045288, "acc": 0.5930501818656921, "length": 1.4930555820465088, "mode": "test", "epoch": 1}
# {"loss": 0.6165874004364014, "acc": 0.6672371625900269, "length": 3.451524496078491, "mode": "train", "epoch": 2}
# {"loss": 0.4957073926925659, "acc": 0.7567707896232605, "length": 4.0, "mode": "test", "epoch": 2}
# {"loss": 0.423886239528656, "acc": 0.8022003769874573, "length": 3.9367873668670654, "mode": "train", "epoch": 3}
# {"loss": 0.4510017931461334, "acc": 0.7805556058883667, "length": 4.0, "mode": "test", "epoch": 3}
# {"loss": 0.3797926604747772, "acc": 0.808565080165863, "length": 3.964993476867676, "mode": "train", "epoch": 4}
# ...

# %% [markdown]
# (3,4) Dataset with no length cost and vocab size 16

# %% [markdown]
# Split

# %%
# !python train.py \
  --dimensions 4 4 4 \
  --n_epochs 300 \
  --batch_size 32 \
  --game_size 10 \
  --scaling_factor 10 \
  --shared_context True \
  --split_by_attribute True \
  --early_stopping True \
  --save_test_interactions_as test_split_3_4 \
  --save_test_interactions True \
  --save True
# Out:
# Using EGG from: C:\Users\metel\OneDrive\Desktop\EGG-final\EGG\egg\__init__.py
# Creating subsets A and B based on randomly chosen attribute. Attribute index: 0
# Subset A size: 1000
# Subset B size: 2000
#
# Final Dataset Sizes:
# Train dataset size: 937
# Validation dataset size: 313
# Test dataset size: 1750
# vocab size 16
# message length 3
# {"loss": 0.6976028680801392, "acc": 0.496158629655838, "length": 3.0258872509002686, "mode": "train", "epoch": 1}
# {"loss": 0.6937651038169861, "acc": 0.5104166865348816, "length": 1.0, "mode": "test", "epoch": 1}
# {"loss": 0.6801713705062866, "acc": 0.5709995627403259, "length": 2.219444513320923, "mode": "train", "epoch": 2}
# {"loss": 0.6460438966751099, "acc": 0.6535319685935974, "length": 2.0208332538604736, "mode": "test", "epoch": 2}
# {"loss": 0.5781478881835938, "acc": 0.6908949017524719, "length": 2.693723678588867, "mode": "train", "epoch": 3}
# ...

# %%
# !python train.py \
  --dimensions 4 4 4 \
  --n_epochs 300 \
  --batch_size 32 \
  --game_size 10 \
  --scaling_factor 10 \
  --shared_context True \
  --split_by_attribute True \
  --early_stopping True \
  --save_test_interactions_as test_split_3_4_run1 \
  --save_test_interactions True \
  --save True
# Out:
# Using EGG from: C:\Users\metel\OneDrive\Desktop\EGG-final\EGG\egg\__init__.py
# Creating subsets A and B based on randomly chosen attribute. Attribute index: 0
# Subset A size: 1000
# Subset B size: 2000
#
# Final Dataset Sizes:
# Train dataset size: 937
# Validation dataset size: 313
# Test dataset size: 1750
# vocab size 16
# message length 3
# {"loss": 0.6976320147514343, "acc": 0.4974864721298218, "length": 3.0841240882873535, "mode": "train", "epoch": 1}
# {"loss": 0.6948392391204834, "acc": 0.49756941199302673, "length": 1.0, "mode": "test", "epoch": 1}
# {"loss": 0.6899094581604004, "acc": 0.5327387452125549, "length": 1.9216928482055664, "mode": "train", "epoch": 2}
# {"loss": 0.6698704957962036, "acc": 0.5960015058517456, "length": 2.53125, "mode": "test", "epoch": 2}
# {"loss": 0.6384709477424622, "acc": 0.6412891745567322, "length": 2.46926212310791, "mode": "train", "epoch": 3}
# ...

# %% [markdown]
# Normal (shared_context, no split)

# %%
# !python train.py \
  --dimensions 4 4 4 \
  --n_epochs 300 \
  --batch_size 32 \
  --game_size 10 \
  --scaling_factor 10 \
  --shared_context True \
  --early_stopping True \
  --save_test_interactions_as test_shared_3_4 \
  --save_test_interactions True \
  --save True
# Out:
# Using EGG from: C:\Users\metel\OneDrive\Desktop\EGG-final\EGG\egg\__init__.py
# Creating train_ds and val_ds...
#
# Creating test_ds...
# vocab size 16
# message length 3
# {"loss": 0.6860957741737366, "acc": 0.5536207556724548, "length": 2.7625699043273926, "mode": "train", "epoch": 1}
# {"loss": 0.6321312785148621, "acc": 0.6864718794822693, "length": 2.4010417461395264, "mode": "test", "epoch": 1}
# {"loss": 0.5422130227088928, "acc": 0.7371598482131958, "length": 2.5150392055511475, "mode": "train", "epoch": 2}
# {"loss": 0.5147261023521423, "acc": 0.7548339366912842, "length": 2.274305582046509, "mode": "test", "epoch": 2}
# {"loss": 0.44404229521751404, "acc": 0.7767179608345032, "length": 2.5997185707092285, "mode": "train", "epoch": 3}
# {"loss": 0.46027305722236633, "acc": 0.7719808220863342, "length": 2.84375, "mode": "test", "epoch": 3}
# {"loss": 0.38799262046813965, "acc": 0.8082453608512878, "length": 3.154694080352783, "mode": "train", "epoch": 4}
# ...

# %%
# !python train.py \
  --dimensions 4 4 4 \
  --n_epochs 300 \
  --batch_size 32 \
  --game_size 10 \
  --scaling_factor 10 \
  --shared_context True \
  --early_stopping True \
  --save_test_interactions_as test_shared_3_4_run1 \
  --save_test_interactions True \
  --save True
# Out:
# Using EGG from: C:\Users\metel\OneDrive\Desktop\EGG-final\EGG\egg\__init__.py
# Creating train_ds and val_ds...
#
# Creating test_ds...
# vocab size 16
# message length 3
# {"loss": 0.6839000582695007, "acc": 0.5566380620002747, "length": 2.9896788597106934, "mode": "train", "epoch": 1}
# {"loss": 0.6193678379058838, "acc": 0.6975368857383728, "length": 3.0208332538604736, "mode": "test", "epoch": 1}
# {"loss": 0.501396894454956, "acc": 0.7520574927330017, "length": 3.0636870861053467, "mode": "train", "epoch": 2}
# {"loss": 0.48715245723724365, "acc": 0.7570393681526184, "length": 3.543402671813965, "mode": "test", "epoch": 2}
# {"loss": 0.34676462411880493, "acc": 0.822738766670227, "length": 3.519754409790039, "mode": "train", "epoch": 3}
# {"loss": 0.4076472222805023, "acc": 0.8187283277511597, "length": 3.616319417953491, "mode": "test", "epoch": 3}
# {"loss": 0.26626601815223694, "acc": 0.8569551706314087, "length": 3.8073840141296387, "mode": "train", "epoch": 4}
# ...

# %% [markdown]
# (3,3) Dataset with length cost 0.002 and vocab size 10

# %% [markdown]
# Split

# %%
# !python train.py \
  --dimensions 3 3 3 \
  --n_epochs 300 \
  --batch_size 32 \
  --game_size 10 \
  --scaling_factor 10 \
  --shared_context True \
  --split_by_attribute True \
  --length_cost 0.002 \
  --vocab_size_factor 0 \
  --vocab_size_user 10 \
  --early_stopping True \
  --save_test_interactions_as test_split_length_3_3 \
  --save_test_interactions True \
  --save True
# Out:
# Using EGG from: C:\Users\metel\OneDrive\Desktop\EGG-final\EGG\egg\__init__.py
# Creating subsets A and B based on randomly chosen attribute. Attribute index: 1
# Subset A size: 480
# Subset B size: 960
#
# Final Dataset Sizes:
# Train dataset size: 450
# Validation dataset size: 150
# Test dataset size: 840
# vocab size 10
# message length 3
# {"loss": 0.704914927482605, "acc": 0.5019088387489319, "length": 3.130983829498291, "mode": "train", "epoch": 1}
# {"loss": 0.6957325339317322, "acc": 0.494140625, "length": 1.0, "mode": "test", "epoch": 1}
# {"loss": 0.6983976364135742, "acc": 0.5043030977249146, "length": 1.5604647397994995, "mode": "train", "epoch": 2}
# {"loss": 0.6977379322052002, "acc": 0.49101564288139343, "length": 1.0, "mode": "test", "epoch": 2}
# {"loss": 0.6913805603981018, "acc": 0.5244420170783997, "length": 1.4698079824447632, "mode": "train", "epoch": 3}
# {"loss": 0.6876276135444641, "acc": 0.5412353873252869, "length": 1.1640625, "mode": "test", "epoch": 3}
# ...

# %%
# !python train.py \
  --dimensions 3 3 3 \
  --n_epochs 300 \
  --batch_size 32 \
  --game_size 10 \
  --scaling_factor 10 \
  --shared_context True \
  --split_by_attribute True \
  --length_cost 0.002 \
  --vocab_size_factor 0 \
  --vocab_size_user 10 \
  --early_stopping True \
  --save_test_interactions_as test_split_length_3_3_run1 \
  --save_test_interactions True \
  --save True
# Out:
# Using EGG from: C:\Users\metel\OneDrive\Desktop\EGG-final\EGG\egg\__init__.py
# Creating subsets A and B based on randomly chosen attribute. Attribute index: 2
# Subset A size: 480
# Subset B size: 960
#
# Final Dataset Sizes:
# Train dataset size: 450
# Validation dataset size: 150
# Test dataset size: 840
# vocab size 10
# message length 3
# {"loss": 0.7069758772850037, "acc": 0.49115246534347534, "length": 3.1417770385742188, "mode": "train", "epoch": 1}
# {"loss": 0.7036802172660828, "acc": 0.48281243443489075, "length": 1.0, "mode": "test", "epoch": 1}
# {"loss": 0.6967049241065979, "acc": 0.5019427537918091, "length": 1.6845887899398804, "mode": "train", "epoch": 2}
# {"loss": 0.7019051313400269, "acc": 0.48085930943489075, "length": 1.0, "mode": "test", "epoch": 2}
# {"loss": 0.6777955293655396, "acc": 0.6117088198661804, "length": 1.797627568244934, "mode": "train", "epoch": 3}
# ...

# %% [markdown]
# Normal (shared_context, no split)

# %%
# !python train.py \
  --dimensions 3 3 3 \
  --n_epochs 300 \
  --batch_size 32 \
  --game_size 10 \
  --scaling_factor 10 \
  --shared_context True \
  --length_cost 0.002 \
  --vocab_size_factor 0 \
  --vocab_size_user 10 \
  --early_stopping True \
  --save_test_interactions_as test_shared_length_3_3 \
  --save_test_interactions True \
  --save True
# Out:
# Using EGG from: C:\Users\metel\OneDrive\Desktop\EGG-final\EGG\egg\__init__.py
# Creating train_ds and val_ds...
#
# Creating test_ds...
# vocab size 10
# message length 3
# {"loss": 0.6946653127670288, "acc": 0.5396064519882202, "length": 2.741779327392578, "mode": "train", "epoch": 1}
# {"loss": 0.6989967226982117, "acc": 0.5140624642372131, "length": 1.0, "mode": "test", "epoch": 1}
# {"loss": 0.6527172923088074, "acc": 0.6217479109764099, "length": 1.9897664785385132, "mode": "train", "epoch": 2}
# {"loss": 0.6023151278495789, "acc": 0.6771484613418579, "length": 2.11328125, "mode": "test", "epoch": 2}
# {"loss": 0.5593993663787842, "acc": 0.7001867890357971, "length": 2.073509454727173, "mode": "train", "epoch": 3}
# {"loss": 0.5732543468475342, "acc": 0.698272705078125, "length": 1.77734375, "mode": "test", "epoch": 3}
# {"loss": 0.5313771963119507, "acc": 0.7160378694534302, "length": 1.914142370223999, "mode": "train", "epoch": 4}
# ...

# %%
# !python train.py \
  --dimensions 3 3 3 \
  --n_epochs 300 \
  --batch_size 32 \
  --game_size 10 \
  --scaling_factor 10 \
  --shared_context True \
  --length_cost 0.002 \
  --vocab_size_factor 0 \
  --vocab_size_user 10 \
  --early_stopping True \
  --save_test_interactions_as test_shared_length_3_3_run1 \
  --save_test_interactions True \
  --save True
# Out:
# Using EGG from: C:\Users\metel\OneDrive\Desktop\EGG-final\EGG\egg\__init__.py
# Creating train_ds and val_ds...
#
# Creating test_ds...
# vocab size 10
# message length 3
# {"loss": 0.7035241723060608, "acc": 0.5171530842781067, "length": 2.92395281791687, "mode": "train", "epoch": 1}
# {"loss": 0.69106525182724, "acc": 0.5378472805023193, "length": 1.0, "mode": "test", "epoch": 1}
# {"loss": 0.6474324464797974, "acc": 0.6509617567062378, "length": 2.2608232498168945, "mode": "train", "epoch": 2}
# {"loss": 0.5430574417114258, "acc": 0.7506673336029053, "length": 2.5833332538604736, "mode": "test", "epoch": 2}
# {"loss": 0.4850275218486786, "acc": 0.761835515499115, "length": 2.9489054679870605, "mode": "train", "epoch": 3}
# {"loss": 0.47153806686401367, "acc": 0.7954915165901184, "length": 3.0833332538604736, "mode": "test", "epoch": 3}
# {"loss": 0.39793553948402405, "acc": 0.8136292695999146, "length": 3.3767170906066895, "mode": "train", "epoch": 4}
# ...

# %% [markdown]
# (3,4) Dataset with length cost 0.002 and vocab size 13

# %% [markdown]
# Split

# %%
# !python train.py \
  --dimensions 4 4 4 \
  --n_epochs 300 \
  --batch_size 32 \
  --game_size 10 \
  --scaling_factor 10 \
  --shared_context True \
  --split_by_attribute True \
  --length_cost 0.002 \
  --vocab_size_factor 0 \
  --vocab_size_user 13 \
  --early_stopping True \
  --save_test_interactions_as test_split_length_3_4 \
  --save_test_interactions True \
  --save True
# Out:
# Using EGG from: C:\Users\metel\OneDrive\Desktop\EGG-final\EGG\egg\__init__.py
# Creating subsets A and B based on randomly chosen attribute. Attribute index: 2
# Subset A size: 1000
# Subset B size: 2000
#
# Final Dataset Sizes:
# Train dataset size: 937
# Validation dataset size: 313
# Test dataset size: 1750
# vocab size 13
# message length 3
# {"loss": 0.7033986449241638, "acc": 0.49413108825683594, "length": 2.3538520336151123, "mode": "train", "epoch": 1}
# {"loss": 0.6932724714279175, "acc": 0.5255208015441895, "length": 1.0, "mode": "test", "epoch": 1}
# {"loss": 0.6950462460517883, "acc": 0.5152167677879333, "length": 1.1275231838226318, "mode": "train", "epoch": 2}
# {"loss": 0.6924647688865662, "acc": 0.5376682281494141, "length": 1.0034722089767456, "mode": "test", "epoch": 2}
# {"loss": 0.6693726778030396, "acc": 0.5810412764549255, "length": 1.8492134809494019, "mode": "train", "epoch": 3}
# ...

# %%
# !python train.py \
  --dimensions 4 4 4 \
  --n_epochs 300 \
  --batch_size 32 \
  --game_size 10 \
  --scaling_factor 10 \
  --shared_context True \
  --split_by_attribute True \
  --length_cost 0.002 \
  --vocab_size_factor 0 \
  --vocab_size_user 13 \
  --early_stopping True \
  --save_test_interactions_as test_split_length_3_4_run2 \
  --save_test_interactions True \
  --save True
# Out:
# Using EGG from: C:\Users\metel\OneDrive\Desktop\EGG-final\EGG\egg\__init__.py
# Creating subsets A and B based on randomly chosen attribute. Attribute index: 0
# Subset A size: 1000
# Subset B size: 2000
#
# Final Dataset Sizes:
# Train dataset size: 937
# Validation dataset size: 313
# Test dataset size: 1750
# vocab size 13
# message length 3
# {"loss": 0.7026698589324951, "acc": 0.49530550837516785, "length": 2.4059081077575684, "mode": "train", "epoch": 1}
# {"loss": 0.6971499919891357, "acc": 0.49270835518836975, "length": 1.0, "mode": "test", "epoch": 1}
# {"loss": 0.6964778900146484, "acc": 0.4977036714553833, "length": 1.066711187362671, "mode": "train", "epoch": 2}
# {"loss": 0.6984958648681641, "acc": 0.47413191199302673, "length": 1.0, "mode": "test", "epoch": 2}
# {"loss": 0.6964564323425293, "acc": 0.5015307664871216, "length": 1.0328741073608398, "mode": "train", "epoch": 3}
# ...

# %% [markdown]
# Normal (shared_context, no split)

# %%
# !python train.py \
  --dimensions 4 4 4 \
  --n_epochs 300 \
  --batch_size 32 \
  --game_size 10 \
  --scaling_factor 10 \
  --shared_context True \
  --length_cost 0.002 \
  --vocab_size_factor 0 \
  --vocab_size_user 13 \
  --early_stopping True \
  --save_test_interactions_as test_shared_length_3_4 \
  --save_test_interactions True \
  --save True
# Out:
# Using EGG from: C:\Users\metel\OneDrive\Desktop\EGG-final\EGG\egg\__init__.py
# Creating train_ds and val_ds...
#
# Creating test_ds...
# C:\Users\metel\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\metel\AppData\Roaming\Python\Python39\site-packages\pandas\core\arrays\masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.4' currently installed).
#   from pandas.core import (
#
# ...
#  25%|██▌       | 25/99 [00:00<00:02, 25.81it/s]
# vocab size 13
# message length 3
# {"loss": 0.6997355222702026, "acc": 0.5083582401275635, "length": 1.7524023056030273, "mode": "train", "epoch": 1}
# {"loss": 0.6957601308822632, "acc": 0.4984375238418579, "length": 1.0, "mode": "test", "epoch": 1}
# ...

# %%
# !python train.py \
  --dimensions 4 4 4 \
  --n_epochs 300 \
  --batch_size 32 \
  --game_size 10 \
  --scaling_factor 10 \
  --shared_context True \
  --length_cost 0.002 \
  --vocab_size_factor 0 \
  --vocab_size_user 13 \
  --early_stopping True \
  --save_test_interactions_as test_shared_length_3_4_run1 \
  --save_test_interactions True \
  --save True
# Out:
# Using EGG from: C:\Users\metel\OneDrive\Desktop\EGG-final\EGG\egg\__init__.py
# C:\Users\metel\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\metel\AppData\Roaming\Python\Python39\site-packages\pandas\core\arrays\masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.4' currently installed).
#   from pandas.core import (
#
# ...
#  15%|█▌        | 15/99 [00:01<00:08,  9.34it/s]
# Creating train_ds and val_ds...
#
# Creating test_ds...
# vocab size 13
# message length 3
# {"loss": 0.697817325592041, "acc": 0.5097535848617554, "length": 1.936411738395691, "mode": "train", "epoch": 1}
# {"loss": 0.6961132884025574, "acc": 0.5099825859069824, "length": 1.0, "mode": "test", "epoch": 1}
# ...

# %% [markdown]
# (4,4) Dataset with no length cost and normal vocab size (16)

# %% [markdown]
# Split

# %%
# !python train.py \
  --dimensions 4 4 4 4 \
  --n_epochs 300 \
  --batch_size 32 \
  --game_size 10 \
  --scaling_factor 10 \
  --shared_context True \
  --split_by_attribute True \
  --early_stopping True \
  --save_test_interactions_as test_split_4_4 \
  --save_test_interactions True \
  --save True
# Out:
# Using EGG from: C:\Users\metel\OneDrive\Desktop\EGG-final\EGG\egg\__init__.py
# Creating subsets A and B based on randomly chosen attribute. Attribute index: 3
# Subset A size: 5000
# Subset B size: 15000
#
# Final Dataset Sizes:
# Train dataset size: 4687
# Validation dataset size: 1563
# Test dataset size: 13750
# C:\Users\metel\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\metel\AppData\Roaming\Python\Python39\site-packages\pandas\core\arrays\masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.4' currently installed).
#   from pandas.core import (
#
# ...
#   9%|▉         | 59/624 [00:05<01:07,  8.32it/s]
# vocab size 16
# message length 4
# ...

# %%
# !python train.py \
  --dimensions 4 4 4 4 \
  --n_epochs 300 \
  --batch_size 32 \
  --game_size 10 \
  --scaling_factor 10 \
  --shared_context True \
  --split_by_attribute True \
  --early_stopping True \
  --save_test_interactions_as test_split_4_4_run1 \
  --save_test_interactions True \
  --save True
# Out:
# Using EGG from: C:\Users\metel\OneDrive\Desktop\EGG-final\EGG\egg\__init__.py
# Creating subsets A and B based on randomly chosen attribute. Attribute index: 2
# Subset A size: 5000
# Subset B size: 15000
#
# Final Dataset Sizes:
# Train dataset size: 4687
# Validation dataset size: 1563
# Test dataset size: 13750
# vocab size 16
# message length 4
# C:\Users\metel\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\metel\AppData\Roaming\Python\Python39\site-packages\pandas\core\arrays\masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.4' currently installed).
#   from pandas.core import (
#
# ...
#   9%|▊         | 54/624 [00:04<01:06,  8.59it/s]
# ...

# %% [markdown]
# No split

# %%
# !python train.py \
  --dimensions 4 4 4 4 \
  --n_epochs 300 \
  --batch_size 32 \
  --game_size 10 \
  --scaling_factor 10 \
  --shared_context True \
  --early_stopping True \
  --save_test_interactions_as test_shared_4_4 \
  --save_test_interactions True \
  --save True
# Out:
# Using EGG from: C:\Users\metel\OneDrive\Desktop\EGG-final\EGG\egg\__init__.py
# Creating train_ds and val_ds...
#
# Creating test_ds...
# vocab size 16
# message length 4
# {"loss": 0.42370596528053284, "acc": 0.7678791284561157, "length": 4.785219192504883, "mode": "train", "epoch": 1}
# {"loss": 0.33691704273223877, "acc": 0.8557292222976685, "length": 5.0, "mode": "test", "epoch": 1}
# {"loss": 0.19510497152805328, "acc": 0.9121072292327881, "length": 4.9965033531188965, "mode": "train", "epoch": 2}
# {"loss": 0.1940924972295761, "acc": 0.923970639705658, "length": 5.0, "mode": "test", "epoch": 2}
# {"loss": 0.12375931441783905, "acc": 0.945850133895874, "length": 4.997968673706055, "mode": "train", "epoch": 3}
# {"loss": 0.14263208210468292, "acc": 0.9420510530471802, "length": 5.0, "mode": "test", "epoch": 3}
# {"loss": 0.08956824988126755, "acc": 0.9626812934875488, "length": 4.9987921714782715, "mode": "train", "epoch": 4}
# ...

# %%
# !python train.py \
  --dimensions 4 4 4 4 \
  --n_epochs 300 \
  --batch_size 32 \
  --game_size 10 \
  --scaling_factor 10 \
  --shared_context True \
  --early_stopping True \
  --save_test_interactions_as test_shared_4_4_run1 \
  --save_test_interactions True \
  --save True
# Out:
# Using EGG from: C:\Users\metel\OneDrive\Desktop\EGG-final\EGG\egg\__init__.py
# Creating train_ds and val_ds...
#
# Creating test_ds...
# vocab size 16
# message length 4
# {"loss": 0.437480092048645, "acc": 0.7602791786193848, "length": 4.231115818023682, "mode": "train", "epoch": 1}
# {"loss": 0.2960241138935089, "acc": 0.8705770373344421, "length": 5.0, "mode": "test", "epoch": 1}
# {"loss": 0.17702549695968628, "acc": 0.9146260023117065, "length": 4.9904584884643555, "mode": "train", "epoch": 2}
# {"loss": 0.15253272652626038, "acc": 0.9244329929351807, "length": 5.0, "mode": "test", "epoch": 2}
# C:\Users\metel\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# ...

# %% [markdown]
# (3,8) dataset with no length cost and normal vocab size (28)

# %% [markdown]
# Split

# %%
# !python train.py \
  --dimensions 8 8 8 \
  --n_epochs 300 \
  --batch_size 32 \
  --game_size 10 \
  --scaling_factor 10 \
  --shared_context True \
  --split_by_attribute True \
  --early_stopping True \
  --save_test_interactions_as test_split_3_8 \
  --save_test_interactions True \
  --save True
# Out:
# Using EGG from: C:\Users\metel\OneDrive\Desktop\EGG-final\EGG\egg\__init__.py
# Creating subsets A and B based on randomly chosen attribute. Attribute index: 2
# Subset A size: 6480
# Subset B size: 12960
#
# Final Dataset Sizes:
# Train dataset size: 6075
# Validation dataset size: 2025
# Test dataset size: 11340
# vocab size 28
# message length 3
# {"loss": 0.6584008932113647, "acc": 0.5786007046699524, "length": 2.7642998695373535, "mode": "train", "epoch": 1}
# {"loss": 0.6380395293235779, "acc": 0.643690288066864, "length": 2.7142856121063232, "mode": "test", "epoch": 1}
# {"loss": 0.5724499225616455, "acc": 0.6982508301734924, "length": 3.614783525466919, "mode": "train", "epoch": 2}
# {"loss": 0.5893393754959106, "acc": 0.7170634269714355, "length": 4.0, "mode": "test", "epoch": 2}
# {"loss": 0.49173402786254883, "acc": 0.7710002064704895, "length": 3.9847829341888428, "mode": "train", "epoch": 3}
# ...

# %%
# !python train.py \
  --dimensions 8 8 8 \
  --n_epochs 300 \
  --batch_size 32 \
  --game_size 10 \
  --scaling_factor 10 \
  --shared_context True \
  --split_by_attribute True \
  --early_stopping True \
  --save_test_interactions_as test_split_3_8_run1 \
  --save_test_interactions True \
  --save True
# Out:
# Using EGG from: C:\Users\metel\OneDrive\Desktop\EGG-final\EGG\egg\__init__.py
# Creating subsets A and B based on randomly chosen attribute. Attribute index: 1
# Subset A size: 6480
# Subset B size: 12960
#
# Final Dataset Sizes:
# Train dataset size: 6075
# Validation dataset size: 2025
# Test dataset size: 11340
# vocab size 28
# message length 3
# {"loss": 0.6458675861358643, "acc": 0.5948039889335632, "length": 3.0309009552001953, "mode": "train", "epoch": 1}
# C:\Users\metel\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\metel\AppData\Roaming\Python\Python39\site-packages\pandas\core\arrays\masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.4' currently installed).
#   from pandas.core import (
#
# ...

# %% [markdown]
# No split

# %%
# !python train.py \
  --dimensions 8 8 8 \
  --n_epochs 300 \
  --batch_size 32 \
  --game_size 10 \
  --scaling_factor 10 \
  --shared_context True \
  --early_stopping True \
  --save_test_interactions_as test_shared_3_8 \
  --save_test_interactions True \
  --save True
# Out:
# Using EGG from: C:\Users\metel\OneDrive\Desktop\EGG-final\EGG\egg\__init__.py
# Creating train_ds and val_ds...
# C:\Users\metel\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\metel\AppData\Roaming\Python\Python39\site-packages\pandas\core\arrays\masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.4' currently installed).
#   from pandas.core import (
#
# ...
#   1%|          | 3/582 [00:00<01:25,  6.80it/s]
# Creating test_ds...
# vocab size 28
# message length 3
# {"loss": 0.568310022354126, "acc": 0.6765052676200867, "length": 3.8228695392608643, "mode": "train", "epoch": 1}
# {"loss": 0.4980018138885498, "acc": 0.7535381317138672, "length": 4.0, "mode": "test", "epoch": 1}
# ...

# %%
# !python train.py \
  --dimensions 8 8 8 \
  --n_epochs 300 \
  --batch_size 32 \
  --game_size 10 \
  --scaling_factor 10 \
  --shared_context True \
  --early_stopping True \
  --save_test_interactions_as test_shared_3_8_run1 \
  --save_test_interactions True \
  --save True
# Out:
# Using EGG from: C:\Users\metel\OneDrive\Desktop\EGG-final\EGG\egg\__init__.py
# Creating train_ds and val_ds...
#
# Creating test_ds...
# vocab size 28
# message length 3
# {"loss": 0.5111184120178223, "acc": 0.7213464379310608, "length": 3.6457176208496094, "mode": "train", "epoch": 1}
# {"loss": 0.4210317134857178, "acc": 0.8099896907806396, "length": 4.0, "mode": "test", "epoch": 1}
# {"loss": 0.3080620765686035, "acc": 0.8609865307807922, "length": 3.9952309131622314, "mode": "train", "epoch": 2}
# {"loss": 0.3465558588504791, "acc": 0.8354636430740356, "length": 4.0, "mode": "test", "epoch": 2}
# {"loss": 0.22328715026378632, "acc": 0.9049903750419617, "length": 3.9981987476348877, "mode": "train", "epoch": 3}
# {"loss": 0.26903069019317627, "acc": 0.8866931200027466, "length": 4.0, "mode": "test", "epoch": 3}
# {"loss": 0.15123409032821655, "acc": 0.9393740892410278, "length": 3.9990382194519043, "mode": "train", "epoch": 4}
# ...
